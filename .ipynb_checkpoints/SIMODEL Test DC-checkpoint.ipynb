# %%
import pySI as SI
import pandas as pd
import numpy as np
import time

#data= pd.DataFrame(pd.read_csv('http://dl.dropbox.com/u/8649795/AT_Austria.csv'))
data = pd.DataFrame(pd.read_csv("C:\\Users\\Taylor\\Documents\\SIMODELTESTDATA1.csv"))
data[['Origin', 'Destination']] = data[['Origin', 'Destination']].astype(str)
#data.Dij = data.Dij/100

# %%
t0 = time.time()

model = SI.calibrate(data=data, trips='Data', sep='Dij', cost='negexp', constraints={'production':'Origin', 'attraction':'Destination'})

results = model.mle(initialParams={'beta':0})
#results = model.regression()

t1 = time.time()
print t1-t0
# Out:
# 18116997103.1 15404669477 2712327626.14
# 18116996464.7
#  15404669477 2712326987.66
# 18114728127.1
#  15404669477 2710058650.13
# 15458259706.0
#  15404669477 53590229.0105
# 15409435905.7
#  15404669477 4766428.73439
# 15405092568.9
#  15404669477 423091.879814
# 15404707024.6
#  15404669477 37547.5783215
# 15404672809.1
#  15404669477 3332.11838531
# 15404669772.7
#  15404669477 295.70479393
# 15404669503.4 15404669477 26.3834056854
# 15404669482.0
#  15404669477 5.04555130005
# After 11 runs, beta is : -0.0007369
# 0.751000165939
# C:\Python27\lib\site-packages\scipy\optimize\minpack.py:236: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
results.results.sum
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-0d15a133ca1e> in <module>()
# ----> 1 results.results.s
#
# C:\Python27\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    1813                 return self[name]
#    1814             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1815                                  (type(self).__name__, name))
#    1816
#    1817     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 's'

# %%
results.data
# Out:
#       Data   Dij Origin Destination        Bj  Ai         OldAi     OldBj  \
# 0   180048   219      1           2  0.943122   0  4.640112e-08  1.146812
# 1    79223  1009      1           3  0.844848   0  4.640112e-08  1.327367
# 2    26887  1514      1           4  0.766919   0  4.640112e-08  1.221497
# 3   198144   974      1           5  0.993898   0  4.640112e-08  1.168009
# 4    17995  1268      1           6  0.725727   0  4.640112e-08  1.179173
# 5    35563  1795      1           7  0.842165   0  4.640112e-08  1.176749
# 6    30528  2420      1           8  0.924756   0  4.640112e-08  1.036139
# 7   110792  3174      1           9  1.982415   0  4.640112e-08  0.921037
# 8   283049   219      2           1  0.852310   0  4.996093e-08  1.020620
# 9   300345   831      2           3  0.844848   0  4.996093e-08  1.327367
# 10   67280  1336      2           4  0.766919   0  4.996093e-08  1.221497
# 11  718673   755      2           5  0.993898   0  4.996093e-08  1.168009
# 12   55094  1049      2           6  0.725727   0  4.996093e-08  1.179173
# 13   93434  1576      2           7  0.842165   0  4.996093e-08  1.176749
# 14   87987  2242      2           8  0.924756   0  4.996093e-08  1.036139
# 15  268458  2996      2           9  1.982415   0  4.996093e-08  0.921037
# 16   87267  1009      3           1  0.852310   0  5.801895e-08  1.020620
# 17  237229   831      3           2  0.943122   0  5.801895e-08  1.146812
# 18  281791   505      3           4  0.766919   0  5.801895e-08  1.221497
# 19  551483  1019      3           5  0.993898   0  5.801895e-08  1.168009
# 56  0.000654   987331   676308 -0.000737   20593.883630
# 57  0.000246   987331  1155811 -0.000737   44403.759305
# 58  0.001518   987331  1789112 -0.000737  110291.414200
# 59  0.000828   987331   942162 -0.000737   76493.860319
#          ...      ...      ...       ...            ...
#
# [72 rows x 13 columns]

# %%
results.results.Data
# Out:
# 0     180048
# 1      79223
# 2      26887
# 3     198144
# 4      17995
# 5      35563
# 6      30528
# 7     110792
# 8     283049
# 9     300345
# 10     67280
# 11    718673
# 12     55094
# 13     93434
# 14     87987
# ...
# 57     43749
# 58     97808
# 59    113683
# 60     89806
# 61     25574
# 62    158006
# 63    437255
# 64     72114
# 65    133122
# 66    229764
# 67    165405
# 68    266305
# 69     66324
# 70    252039
# 71    342948
# Name: Data, Length: 72, dtype: int64

# %%
results.results.params
# Out:
# Intercept           11.448836
# Destination[T.2]     0.637154
# Destination[T.3]     0.964032
# Destination[T.4]     0.225959
# Destination[T.5]     1.454816
# Destination[T.6]     0.030930
# Destination[T.7]     0.591884
# Destination[T.8]     0.537601
# Destination[T.9]     1.997514
# Origin[T.2]          0.996608
# Origin[T.3]          1.049487
# Origin[T.4]          0.361108
# Origin[T.5]          1.146618
# Origin[T.6]          0.114941
# Origin[T.7]          0.414284
# Origin[T.8]          0.267321
# Origin[T.9]          1.582179
# Dij                 -0.000737
# dtype: float64

# %%
np.sum(data.Data*data.Dij)/np.sum(data.Data)
# Out:
# 1250

# %%
np.sum(results.results.SIM_Estimates*data.Dij)/np.sum(results.results.SIM_Estimates)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-36c036491bac> in <module>()
# ----> 1 np.sum(results.results.SIM_Estimates*data.Dij)/np.sum(results.results.SIM_Estimates)
#
# C:\Python27\lib\site-packages\statsmodels\base\wrapper.pyc in __getattribute__(self, attr)
#      33             pass
#      34
# ---> 35         obj = getattr(results, attr)
#      36         data = results.model.data
#      37         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'GLMResults' object has no attribute 'SIM_Estimates'

# %%
np.sum(results.results.SIM_Estimates)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-e3eb1fab74b3> in <module>()
# ----> 1 np.sum(results.results.SIM_Estimates)
#
# C:\Python27\lib\site-packages\statsmodels\base\wrapper.pyc in __getattribute__(self, attr)
#      33             pass
#      34
# ---> 35         obj = getattr(results, attr)
#      36         data = results.model.data
#      37         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'GLMResults' object has no attribute 'SIM_Estimates'

# %%
results.results.bse
# Out:
# Intercept           0.001840
# Destination[T.2]    0.001560
# Destination[T.3]    0.001442
# Destination[T.4]    0.001608
# Destination[T.5]    0.001391
# Destination[T.6]    0.001653
# Destination[T.7]    0.001527
# Destination[T.8]    0.001599
# Destination[T.9]    0.001531
# Origin[T.2]         0.001440
# Origin[T.3]         0.001409
# Origin[T.4]         0.001534
# Origin[T.5]         0.001449
# Origin[T.6]         0.001591
# Origin[T.7]         0.001545
# Origin[T.8]         0.001637
# Origin[T.9]         0.001553
# Dij                 0.000001
# dtype: float64
