# %%
import pandas as pd
import geopandas as gp
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['test']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
states = gp.read_file("C:\pandasTest\states.shp")
states = states.rename(columns={'STATE_NAME':'NAME'})
populations = pd.read_csv("C:\pandasTest\populations.csv")
populations.set_index('NAME', inplace=True)

# %%
joined = states.join(populations, on='NAME')
#states.merge(populations, on='NAME')

# %%
type(states)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# Out:
#     DRAWSEQ STATE_ABBR STATE_FIPS                  NAME          SUB_REGION  \
# 0         1         HI         15                Hawaii             Pacific
# 1         2         WA         53            Washington             Pacific
# 2         3         MT         30               Montana            Mountain
# 3         4         ME         23                 Maine         New England
# 4         5         ND         38          North Dakota  West North Central
# 5         6         SD         46          South Dakota  West North Central
# 6         7         WY         56               Wyoming            Mountain
# 7         8         WI         55             Wisconsin  East North Central
# 8         9         ID         16                 Idaho            Mountain
# 9        10         VT         50               Vermont         New England
# 10       11         MN         27             Minnesota  West North Central
# ...
